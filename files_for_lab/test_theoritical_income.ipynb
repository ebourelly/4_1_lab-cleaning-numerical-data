# %% [markdown]
# # 1. Import the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
customer_df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %% [markdown]
# # 3. First look at its main features (head, shape, info).

# %%
customer_df. head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
customer_df.info
# Out:
# <bound method DataFrame.info of      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]>

# %% [markdown]
# # 4. Rename the columns so they follow the PE8 (snake case) (lower_case_with_underscores)

# %%
customer_df = customer_df.rename(columns={'EmploymentStatus': 'Employment Status'})
customer_df.columns = [colname.lower().replace(' ','_') for colname in customer_df.columns]
display(customer_df.columns)
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employment_status', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# # 5. Change effective to date column to datetime format.

# %%
customer_df['effective_to_Date'] = pd.to_datetime(customer_df['effective_to_date'], errors='coerce')
customer_df.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                        object
# employment_status                        object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# sales_channel                            object
# total_claim_amount                      float64
# vehicle_class                            object
# vehicle_size                             object
# effective_to_Date                datetime64[ns]
# dtype: object

# %% [markdown]
# # 6. Define a function that differentiates between continuous and discrete variables.
# ### Hint: The number of unique values might be useful. Store continuous data into a continuous_df variable and do the same for discrete_df

# %%
customer_df_num = customer_df._get_numeric_data()
customer_df_num
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %%
# Let's look at the number of unique values for each numerical column
for col in customer_df_num.columns:
    print(col, 'has', len(customer_df_num[col].unique()), 'unique values')
    display(customer_df_num[col].unique())
# Out:
# customer_lifetime_value has 8041 unique values
# array([ 2763.519279,  6979.535903, 12887.43165 , ...,  8163.890428,
#         7524.442436,  2611.836866])
# income has 5694 unique values
# array([56274,     0, 48767, ..., 66367, 71941, 21941], dtype=int64)
# monthly_premium_auto has 202 unique values
# array([ 69,  94, 108, 106,  73,  67, 101,  71,  93, 110,  70,  64,  72,
#         74,  79,  61, 111, 139,  80,  63, 237,  65,  62, 117,  91,  90,
#         66,  99, 103, 172,  92, 104, 113, 124, 105, 100, 112,  97,  95,
#        102, 186,  77,  96,  76, 119,  88, 109, 107, 130,  85,  98, 133,
#         86,  78,  83,  68, 192, 118,  89, 140, 127, 168, 126,  82, 115,
#        217, 114, 138,  81, 255, 150, 123, 116, 190, 159,  84, 152, 136,
#        245, 135, 128, 225, 132, 153, 121, 154, 161, 156, 171,  87, 244,
#        183, 176, 230, 129, 177, 196, 131, 276, 253, 137, 180, 203, 147,
#        165, 198, 125, 193, 271, 188, 142, 206, 182, 189, 160, 295, 210,
#        134, 239, 256, 173, 285, 148, 197, 199, 214, 175, 167, 194, 164,
#        181, 222, 215, 283, 169, 248, 223, 273, 151, 213, 145, 185, 287,
#        297, 201, 149, 146, 235, 268, 211, 187, 141, 242, 170, 122, 143,
#        155, 166, 212, 249, 240, 191, 195, 216, 144, 179, 232, 158, 207,
#        184, 238, 229, 220, 178, 204, 281, 234, 218, 275, 209, 261, 157,
#        205, 228, 284, 231, 208, 296, 202, 162, 274, 219, 247, 290, 226,
#        163, 298, 266, 254, 252, 174, 286], dtype=int64)
# months_since_last_claim has 36 unique values
# array([32, 13, 18, 12, 14,  0, 17, 23, 27,  9, 21, 11, 31,  8,  4, 30, 22,
#        15, 33,  1, 19, 28, 10,  7,  3,  5, 20, 24, 29, 34,  6, 35,  2, 16,
#        26, 25], dtype=int64)
# months_since_policy_inception has 100 unique values
# array([ 5, 42, 38, 65, 44, 94, 13, 68,  3,  7, 87, 82, 25, 10, 50, 59,  1,
#        21, 49, 91, 47, 64, 54,  6, 14, 56, 17, 40, 62, 86, 79, 15, 32, 28,
#        16,  4, 57, 77, 95, 26, 53, 12, 98, 36, 71, 60, 20,  0, 27, 48, 33,
#        83, 30, 69, 90, 81, 84, 88, 18, 11, 85, 93, 34, 89,  2, 70, 37, 43,
#         8, 35, 99, 55, 75, 51, 92, 29, 63, 61, 46, 41, 31, 45, 67, 22, 23,
#         9, 72, 96, 58, 66, 73, 39, 19, 97, 52, 76, 78, 80, 74, 24],
#       dtype=int64)
# number_of_open_complaints has 6 unique values
# array([0, 2, 1, 3, 5, 4], dtype=int64)
# number_of_policies has 9 unique values
# array([1, 8, 2, 7, 9, 4, 3, 6, 5], dtype=int64)
# total_claim_amount has 5106 unique values
# array([ 384.811147, 1131.464935,  566.472247, ...,  541.282007,
#         198.234764,  790.784983])

# %% [markdown]
# We see we have that out of the 8 columns, 3 have more than 5.000 unique values, whereas the other ones have a much lower amount.
# Those are definitely continuous variable, even though the income column only shows integer figures. Those are probably just rounded amounts that can be considered continuous. Same happens for the monthly premium, even if the number of unique values is much lower (202).
# The 4 other columns contain variables that count elements and are discrete.
#
# To use a function, I'll set a 200 unique values limit to split the two types of variables.

# %%
def column_category(colname):
    if len(colname.unique()) >= 200:    # checks for each column the number of unique values
        return "continuous"       # returns continuous if the column has more than 1.000 unique values
    else:
        return "discrete"

# %%
continuous_columns = []
discrete_columns = []

for colname in customer_df_num.columns:
    if column_category(customer_df_num[colname]) == "continuous":
        continuous_columns.append(colname)
    else:
        discrete_columns.append(colname)

# %%
continuous_df = customer_df_num[continuous_columns].copy()
continuous_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       total_claim_amount
# 0             384.811147
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4             138.130879
# ...                  ...
# 9129          198.234764
# 9130          379.200000
# 9131          790.784983
# 9132          691.200000
# 9133          369.600000
#
# [9134 rows x 4 columns]

# %%
discrete_df = customer_df_num[discrete_columns].copy()
discrete_df
# Out:
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies
# 0                             0                   1
# 1                             0                   8
# 2                             0                   2
# 3                             0                   7
# 4                             0                   1
# ...                         ...                 ...
# 9129                          0                   2
# 9130                          0                   1
# 9131                          3                   2
# 9132                          0                   3
# 9133                          0                   1
#
# [9134 rows x 4 columns]

# %% [markdown]
# # 7. Plot a correlation matrix, comment what you see.

# %%
corr_matrix = customer_df.corr()
corr_matrix
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# months_since_last_claim                    0.005026                 1.000000
# months_since_policy_inception              0.020257                -0.042959
# number_of_open_complaints                 -0.013122                 0.005354
# number_of_policies                        -0.011233                 0.009136
# total_claim_amount                         0.632017                 0.007563
#
#                                months_since_policy_inception  \
# customer_lifetime_value                             0.009418
# income                                             -0.000875
# monthly_premium_auto                                0.020257
# months_since_last_claim                            -0.042959
# months_since_policy_inception                       1.000000
# number_of_open_complaints                          -0.001158
# number_of_policies                                 -0.013333
# total_claim_amount                                  0.003335
#
#                                number_of_open_complaints  number_of_policies  \
# customer_lifetime_value                        -0.036343            0.021955
# income                                          0.006408           -0.008656
# monthly_premium_auto                           -0.013122           -0.011233
# months_since_last_claim                         0.005354            0.009136
# months_since_policy_inception                  -0.001158           -0.013333
# number_of_open_complaints                       1.000000            0.001498
# number_of_policies                              0.001498            1.000000
# total_claim_amount                             -0.014241           -0.002354
#
#                                total_claim_amount
# customer_lifetime_value                  0.226451
# income                                  -0.355254
# monthly_premium_auto                     0.632017
# months_since_last_claim                  0.007563
# months_since_policy_inception            0.003335
# number_of_open_complaints               -0.014241
# number_of_policies                      -0.002354
# total_claim_amount                       1.000000

# %%
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# From the correlation matrix or heatmap, we see that none of the columns is strongly correlated to another.
# The strongest correlations are between monthly premium and total claim amount (0.63) and between customer lifetime and monthly premium auto. In both cases, the correlation seems pretty logical, but they are not strong enough to justify dropping one of the columns.

# %% [markdown]
# # 8. Create a function to plot every discrete variable. Do the same with the continuous variables
# ### Be Careful, you may need to change the plot type to one better suited for continuous data!

# %%
def discrete_plot(df):
    for var in df.columns:
        sns.displot(df[var])
        plt.show()

# %%
discrete_plot(discrete_df)

# %%
# for the continuous variables, I will apply a box plot
def continuous_box_plot(df):
    for vars_ in df.columns:
        sns.boxplot(y=df[vars_])
        plt.show()
        
continuous_box_plot(continuous_df)

# %% [markdown]
# # 9-10-11. Comment what you can see in the plots.
# # Look for outliers in the continuous variables. If you find some, what will you do with them ?

# %% [markdown]
# ## Discrete variables

# %% [markdown]
# #### Months since last claim
# The distribution is more flat here. The range is going from 1 to 36 months. Maybe we can split the column in three categories, less than one year, less than 2 years, more than 2 years.

# %%
def clean_month_since_claim(x):
    if x <= 12:
        return '< 1y'
    elif x <= 24:
        return '< 2y'
    else:
        return '> 2y'

customer_df['months_since_last_claim'] = customer_df['months_since_last_claim'].apply(clean_month_since_claim)
customer_df['months_since_last_claim'].value_counts()
# Out:
# < 1y    4119
# < 2y    3004
# > 2y    2011
# Name: months_since_last_claim, dtype: int64

# %% [markdown]
# #### Months since policy inception
# Same obeservation as for the months since last claims, the distribution is flat. This time, it ranges from 0 to roughly 100 mnonths, which I will cut in segments of 2 years.

# %%
def clean_month_since_inception(x):
    if x <= 24:
        return '< 2y'
    elif x <= 48:
        return '< 4y'
    elif x <= 72:
        return '< 6y'
    else:
        return '> 6y'

customer_df['months_since_policy_inception'] = customer_df['months_since_policy_inception'].apply(clean_month_since_inception)
customer_df['months_since_policy_inception'].value_counts()
# Out:
# < 6y    2337
# < 4y    2325
# < 2y    2307
# > 6y    2165
# Name: months_since_policy_inception, dtype: int64

# %% [markdown]
# #### Number of open complaints
# We see  that a huge majority of the contracts does not have any open complaint. The number of contracts with open complaints is very low for each of the other amounts (1 to 5 maximum). I will transform this column in a sort of boolean info : open coplaint or not ?

# %%
customer_df['number_of_open_complaints'] = np.where(customer_df['number_of_open_complaints'] == 0, 'No', 'Yes')
customer_df['number_of_open_complaints'].value_counts()
# Out:
# No     7252
# Yes    1882
# Name: number_of_open_complaints, dtype: int64

# %% [markdown]
# #### Number of policies
# Same story here, we have a great majority of the contracts having 1, 2 or 3 policies. The amounts greater than 3 (4 to 9) have more or less the same population of around 500.
# To avoid overweighting those contracts with lots of policies if we regroup them all, we could create 2 sub categorie to regroup the contracts between 4 and 6 and those between 7 and 9.

# %%
def clean_policies(x):
    if x <= 3:
        return x
    elif x<= 6:
        return '4-6'
    else:
        return '7-9'

customer_df['number_of_policies'] = customer_df['number_of_policies'].apply(clean_policies)
customer_df['number_of_policies'].value_counts()
# Out:
# 1      3251
# 2      2294
# 7-9    1233
# 4-6    1188
# 3      1168
# Name: number_of_policies, dtype: int64

# %% [markdown]
# ## Continuous variables

# %%
continuous_df.describe().T
# Out:
#                           count          mean           std          min  \
# customer_lifetime_value  9134.0   8004.940475   6870.967608  1898.007675
# income                   9134.0  37657.380009  30379.904734     0.000000
# monthly_premium_auto     9134.0     93.219291     34.407967    61.000000
# total_claim_amount       9134.0    434.088794    290.500092     0.099007
#
#                                  25%           50%           75%           max
# customer_lifetime_value  3994.251794   5780.182197   8962.167041  83325.381190
# income                      0.000000  33889.500000  62320.000000  99981.000000
# monthly_premium_auto       68.000000     83.000000    109.000000    298.000000
# total_claim_amount        272.258244    383.945434    547.514839   2893.239678

# %% [markdown]
# #### Customer lifetime value
# The lifetime variable shows a wide range of values, going from roughly 2000 to 85000.
# The boxplot shows that this variable have some outliers in the highest values, but there seem to be lots of them, so dropping them might not be the best solution.
# We furthermore do not know how this value is expressed. What can an average lifetime of 8005 mean ? That makes us difficult to understand if the outliers are errors or just actually "older" customers.

# %%
iqr_lifetime = np.percentile(customer_df['customer_lifetime_value'],75) - np.percentile(customer_df['customer_lifetime_value'],25)
upper_limit_lifetime = np.percentile(customer_df['customer_lifetime_value'],75) + 1.5*iqr_lifetime
print(upper_limit_lifetime)
extraordinary_points_lifetime = customer_df[customer_df['customer_lifetime_value'] > upper_limit_lifetime]
print(len(extraordinary_points_lifetime))
# Out:
# 16414.039911750002
# 817

# %% [markdown]
# Droping the outliers would thus mean "losing" 817 rows out of 9134. That is quite a lot od data to lose.

# %% [markdown]
# #### Income
# Income range from 0 to almost 100000. This is a wide range but the plot for this variable does not show outliers.
# However, the data quality issue relies for me more in the fact that we see that at least the full first quartile is made of customers with 0 income. I guess that this is not possible and shows missing data.

# %%
customer_df[customer_df['income']==0]['employment_status'].value_counts()
# Out:
# Unemployed    2317
# Name: employment_status, dtype: int64

# %% [markdown]
# We thus have 2317 contracts showing no income at all for customers that would be unemployed. This is 25% of the data and seems like an incredibly huge part of the customer portfolio. We thus cannot simply drop those rows.

# %%
sns.displot(customer_df['income'])
plt.show()

# %% [markdown]
# Replacing those 25% of data with one and only amount would also not really make sens, as it would completely modify the distribution of the data.
# Let's make a quick KNN regression to fill in those rows.

# %%
customer_df_num
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %%
numericals_with_income = customer_df_num[customer_df_num['income'] != 0]
numericals_with_income
X_income = numericals_with_income.drop(['income', 'months_since_last_claim', 'number_of_open_complaints','total_claim_amount'],axis=1)
# I drop the columns that I do not think relevant or might be targets later on
y_income = numericals_with_income['income']
y_income
# Out:
# 0       56274
# 2       48767
# 4       43836
# 5       62902
# 6       55350
#         ...
# 9127    66367
# 9128    47761
# 9129    71941
# 9130    21604
# 9132    21941
# Name: income, Length: 6817, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
X_normalized_income = pd.DataFrame(MinMaxScaler().fit_transform(X_income), columns=X_income.columns)
KNN = KNeighborsClassifier(n_neighbors=3)
KNN.fit(X_normalized_income,y_income)
KNN.score(X_normalized_income,y_income)
# Out:
# 0.43626228546281354

# %%
X_all = customer_df_num.drop(['income', 'months_since_last_claim', 'number_of_open_complaints','total_claim_amount'],axis=1)
X_normalized_all = pd.DataFrame(MinMaxScaler().fit_transform(X_all), columns=X_all.columns)
y_all = customer_df_num['income']

# %%
predicted_income = pd.Series(KNN.predict(X_normalized_all),name='predicted_income')
predicted_income
# Out:
# 0       31385
# 1       30852
# 2       48767
# 3       20538
# 4       20327
#         ...
# 9129    17257
# 9130    21604
# 9131    24589
# 9132    21941
# 9133    38870
# Name: predicted_income, Length: 9134, dtype: int64

# %%
customer_df = pd.concat([customer_df,predicted_income],axis=1)
customer_df[['income','predicted_income']].head(25)
# Out:
#     income  predicted_income
# 0    56274             31385
# 1        0             30852
# 2    48767             48767
# 3        0             20538
# 4    43836             20327
# 5    62902             62902
# 6    55350             55350
# 7        0             26380
# 8    14072             14072
# 9    28812             28812
# 10       0             10269
# 11       0             18141
# 12   77026             20169
# 13   99845             99845
# 14   83689             12153
# 15   24599             24599
# 16   25049             25049
# 17   28855             28855
# 18   51148             34528
# 19   66140             62588
# 20   57749             23893
# 21   13789             13789
# 22   14072             14072
# 23       0             20327
# 24   17870             17870

# %% [markdown]
# Let's check if the two columns return similar average values

# %%
customer_df.income.mean()
# Out:
# 37657.38000875848

# %%
customer_df.predicted_income.mean()
# Out:
# 34041.97613312897

# %%
# We need to let the income at 0 for customers who are unemployed
customer_df['final_income'] =  np.where((customer_df['income'] != 0) | (customer_df['employment_status'] == 'Unemployed'), customer_df['income'], customer_df['predicted_income'])
customer_df.head(15)
# Out:
#    customer       state  customer_lifetime_value response  coverage  \
# 0   BU79786  Washington              2763.519279       No     Basic
# 1   QZ44356     Arizona              6979.535903       No  Extended
# 2   AI49188      Nevada             12887.431650       No   Premium
# 3   WW63253  California              7645.861827       No     Basic
# 4   HB64268  Washington              2813.692575       No     Basic
# 5   OC83172      Oregon              8256.297800      Yes     Basic
# 6   XZ87318      Oregon              5380.898636      Yes     Basic
# 7   CF85061     Arizona              7216.100311       No   Premium
# 8   DY87989      Oregon             24127.504020      Yes     Basic
# 9   BQ94931      Oregon              7388.178085       No  Extended
# 10  SX51350  California              4738.992022       No     Basic
# 11  VQ65197  California              8197.197078       No     Basic
# 12  DP39365  California              8798.797003       No   Premium
# 13  SJ95423     Arizona              8819.018934      Yes     Basic
# 14  IL66569  California              5384.431665       No     Basic
#
#                education effective_to_date employment_status gender  income  \
# 0               Bachelor           2/24/11          Employed      F   56274
# 1               Bachelor           1/31/11        Unemployed      F       0
# 2               Bachelor           2/19/11          Employed      F   48767
# 3               Bachelor           1/20/11        Unemployed      M       0
# 4               Bachelor            2/3/11          Employed      M   43836
# 5               Bachelor           1/25/11          Employed      F   62902
# 6                College           2/24/11          Employed      F   55350
# 7                 Master           1/18/11        Unemployed      M       0
# 8               Bachelor           1/26/11     Medical Leave      M   14072
# 9                College           2/17/11          Employed      F   28812
# 10               College           2/21/11        Unemployed      M       0
# 11               College            1/6/11        Unemployed      F       0
# 12                Master            2/6/11          Employed      M   77026
# 13  High School or Below           1/10/11          Employed      M   99845
# 14               College           1/18/11          Employed      M   83689
#
#     ...        policy renew_offer_type  sales_channel total_claim_amount  \
# 0   ...  Corporate L3           Offer1          Agent         384.811147
# 1   ...   Personal L3           Offer3          Agent        1131.464935
# 2   ...   Personal L3           Offer1          Agent         566.472247
# 3   ...  Corporate L2           Offer1    Call Center         529.881344
# 4   ...   Personal L1           Offer1          Agent         138.130879
# 5   ...   Personal L3           Offer2            Web         159.383042
# 6   ...  Corporate L3           Offer1          Agent         321.600000
# 7   ...  Corporate L3           Offer1          Agent         363.029680
# 8   ...  Corporate L3           Offer1          Agent         511.200000
# 9   ...    Special L2           Offer2         Branch         425.527834
# 10  ...   Personal L3           Offer1          Agent         482.400000
# 11  ...   Personal L3           Offer2          Agent         528.000000
# 12  ...  Corporate L1           Offer2          Agent         472.029737
# 13  ...  Corporate L3           Offer2         Branch         528.000000
# 14  ...  Corporate L3           Offer4    Call Center         307.139132
#
#     vehicle_class vehicle_size effective_to_Date income_category  \
# 0    Two-Door Car      Medsize        2011-02-24            High
# 1   Four-Door Car      Medsize        2011-01-31             Low
# 2    Two-Door Car      Medsize        2011-02-19        Moderate
# 3             SUV      Medsize        2011-01-20             Low
# 4   Four-Door Car      Medsize        2011-02-03        Moderate
# 5    Two-Door Car      Medsize        2011-01-25            High
# 6   Four-Door Car      Medsize        2011-02-24            High
# 7   Four-Door Car      Medsize        2011-01-18             Low
# 8   Four-Door Car      Medsize        2011-01-26             Low
# 9   Four-Door Car      Medsize        2011-02-17        Moderate
# 10  Four-Door Car        Small        2011-02-21             Low
# 11            SUV      Medsize        2011-01-06             Low
# 12  Four-Door Car      Medsize        2011-02-06       Very High
# 13            SUV      Medsize        2011-01-10       Very High
# 14  Four-Door Car      Medsize        2011-01-18       Very High
#
#    predicted_income final_income
# 0             31385        56274
# 1             30852            0
# 2             48767        48767
# 3             20538            0
# 4             20327        43836
# 5             62902        62902
# 6             55350        55350
# 7             26380            0
# 8             14072        14072
# 9             28812        28812
# 10            10269            0
# 11            18141            0
# 12            20169        77026
# 13            99845        99845
# 14            12153        83689
#
# [15 rows x 28 columns]

# %%
customer_df.final_income.mean()
# Out:
# 45799.41197722794

# %%
sns.displot(customer_df['final_income'])
plt.show()

# %%
But we also saw that the correlation between income and other elements is low, so binning the data would not lead to a significant loss of data.

# %%
# Let's first see an automatic binning by panda
income_labels = ['Low', 'Moderate', 'High', 'Very High']
customer_df['income_category'] = pd.cut(customer_df['income'],4,labels=income_labels)
customer_df[['income','income_category']].head(20)
# Out:
#     income income_category
# 0    56274            High
# 1        0             Low
# 2    48767        Moderate
# 3        0             Low
# 4    43836        Moderate
# 5    62902            High
# 6    55350            High
# 7        0             Low
# 8    14072             Low
# 9    28812        Moderate
# 10       0             Low
# 11       0             Low
# 12   77026       Very High
# 13   99845       Very High
# 14   83689       Very High
# 15   24599             Low
# 16   25049        Moderate
# 17   28855        Moderate
# 18   51148            High
# 19   66140            High

# %%
customer_df['income_category'].value_counts()
# Out:
# Low          3529
# Moderate     2333
# High         1925
# Very High    1347
# Name: income_category, dtype: int64

# %%
# Let'snow apply a binning per quartile
customer_df['income_category_quartiles'] = pd.qcut(customer_df['income'],4,labels=income_labels)
customer_df[['income','income_category_quartiles']].head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19416/3310824747.py in <module>
#       1 # Let'snow apply a binning per quartile
# ----> 2 customer_df['income_category_quartiles'] = pd.qcut(customer_df['income'],4,labels=income_labels)
#       3 customer_df[['income','income_category_quartiles']].head(20)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     370         quantiles = q
#     371     bins = algos.quantile(x, quantiles)
# --> 372     fac, bins = _bins_to_cuts(
#     373         x,
#     374         bins,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     411     if len(unique_bins) < len(bins) and len(bins) != 2:
#     412         if duplicates == "raise":
# --> 413             raise ValueError(
#     414                 f"Bin edges must be unique: {repr(bins)}.\n"
#     415                 f"You can drop duplicate edges by setting the 'duplicates' kwarg"
#
# ValueError: Bin edges must be unique: array([    0. ,     0. , 33889.5, 62320. , 99981. ]).
# You can drop duplicate edges by setting the 'duplicates' kwarg

# %%
This does not work, as we apparently have more than 25% of our data with an income at 0.

# %% [markdown]
# #### Monthly Premium Auto
# We see that the distribution is mainly centered on premium amounts below the 150€.
# The range tops up at around 300€, which does seem unconsistant, as expensive cars or bad driving history can explain a higher premium. Maybe we can split the monthly premium in bins, so that we end up with a few limited number of categories.

# %% [markdown]
# #### Total claim amount

# %% [markdown]
# # 10. Look for outliers in the continuous variables. (HINT: There’s a good plot to do that!)

# %% [markdown]
# # 11. Did you find outliers? Comment what you will do with them.

# %% [markdown]
# # 12. Check all columns for NaN values. Decide what (if anything) you will need to do with them

# %%
customer_df.isnull().sum()
